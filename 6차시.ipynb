# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">생각대로 PYTHON: 파이썬 첫걸음</div>
#     <div style="font-weight: bold; font-size: 20px">(6) 반복 for 알아보기</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; for문으로 반복하기 <br>
# </div>

# %% [markdown]
# <div style="font-weight: bold; font-size: 20px">
#     Overview
# </div>
#
# <div style="padding: 15px; border: 6px solid transparent; border-color: transparent; margin-bottom: 20px;   border-color: #E0D3E4; font-weight: bold;">
#
#  ![image.png](attachment:8b9139d3-cb43-472a-aa72-5b0f9403d9e6.png)
#
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 주어진 자료로 반복하는 for</h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:3e5a546b-3d5b-45f8-9c93-10ebb29de4c8.png)
# ![image.png](attachment:073093f6-de41-4a65-bc28-2eff2c0c598f.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. for문 어떻게 사용할까?</h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:0ce8c577-3400-412c-8076-56b94a318944.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 예제로 for문 살펴보기</h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:b088f5bf-8962-49e7-aedc-5fd097527e05.png)
# ![image.png](attachment:2698196e-d55c-44ee-8b54-4426c9cec95e.png)

# %%
for i in range(3):
    print('Hello, Python!')

# %% [markdown]
# ![image.png](attachment:48e8e48b-213e-4931-a5ba-a5d97513babf.png)
# ![image.png](attachment:70f5bdf9-84e8-4ca8-a32a-f53ba938bfd5.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3baea0; border-color: #93e4c1;">
#     <div style="font-weight: bold; font-size: 20px">💯 Checking Point</div>
#     <br>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="Q0A6ykpTPKE" href='#jce-judge/open/Q0A6ykpTPKE' target='_self'><span>이상한 기호 여러번 출력하기_빈칸</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="2ZQPvH7c2-0" href='#jce-judge/open/2ZQPvH7c2-0' target='_self'><span>계산기</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="NO4J_EebgyY" href='#jce-judge/open/NO4J_EebgyY' target='_self'><span>문자 찾기</span></a>
#
#
#
#
#
#
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #946163;  border-color: #C27F82; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">🤓 Jump Up</div>
#
# 제어문(조건문, 반복문) 심화 연습문제
#  <br>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="-l6jVCapBY0" href='#jce-judge/open/-l6jVCapBY0' target='_self'><span>주민등록번호</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="ieL1WX9CSi0" href='#jce-judge/open/ieL1WX9CSi0' target='_self'><span>철수 수트레인지</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="Q9K24VZlC8I" href='#jce-judge/open/Q9K24VZlC8I' target='_self'><span>검열  </span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="KcDVh1s9VRw" href='#jce-judge/open/KcDVh1s9VRw' target='_self'><span>자릿수 더하기</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="XsQS4hmfOTA" href='#jce-judge/open/XsQS4hmfOTA' target='_self'><span>회문 암호</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="nabLkmsleUg" href='#jce-judge/open/nabLkmsleUg' target='_self'><span>숫자 피라미드</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="CJBmM4jR0kA" href='#jce-judge/open/CJBmM4jR0kA' target='_self'><span>미션: 가위바위보3</span></a>
#
#
#
#
#
#
#
# </div>
