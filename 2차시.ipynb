# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">생각대로 PYTHON: 파이썬 첫걸음</div>
#     <div style="font-weight: bold; font-size: 20px">(2) 기본 데이터 알아보기</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 데이터 타입 및 처리 <br>
#     &#x2022; 숫자, 문자열, 논리 데이터<br>
# </div>

# %% [markdown]
# <div style="font-weight: bold; font-size: 20px">
#     Overview
# </div>
#
# <div style="padding: 15px; border: 6px solid transparent; border-color: transparent; margin-bottom: 20px; border-color: #E0D3E4; font-weight: bold;">
#
#
#  ![image.png](attachment:d462a543-179a-47e2-9571-92806c37e547.png)
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 데이터 타입 및 처리</h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:f4caee3c-9fb8-46a8-8313-7e0e847859b2.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 데이터 타입의 종류</h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:588af863-d710-48a5-8013-dac95e893877.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 숫자를 나타내는 숫자 데이터</h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:276fa5c7-829b-4cf1-96f1-230e7a2fcc51.png)
# ![image.png](attachment:9f7a3f43-8633-402d-a1de-20a71a697699.png)

# %%
print(13+5)
print(13-5)
print(13*5)
print(13/5)

# %% [markdown]
# ![image.png](attachment:d766ebb4-5554-4601-bfc4-8c552d13484e.png)

# %%
print(13/5)
print(13//5)

# %% [markdown]
# ![image.png](attachment:561b4ca0-46e2-49b6-8c98-74a1d2147d33.png)

# %% [markdown]
# ![image.png](attachment:f753deb0-d7f2-4db4-807d-fcf7bb341b55.png)

# %%
print(13%5)

# %% [markdown]
# ![image.png](attachment:bdd9105d-7f54-43a6-a182-28f983a6f7ce.png)

# %% [markdown]
# ![image.png](attachment:ad715236-1fb4-4f75-96df-775699eb0829.png)

# %%
print(13**5)

# %% [markdown]
# ![image.png](attachment:ca538cfa-d166-4fd5-b523-3d2adec3ef64.png)

# %%
# 5687을 12로 나누었을때 몫 구하기 
print(5687//12)

# %%
# 5687을 12로 나누었을 때 나머지 구하기
print(5687%12)

# %% [markdown]
# ![image.png](attachment:7c03e8c0-8774-40f4-b49b-3abc2048d433.png)

# %%
# 1번
print(20 - 5 * 3)

# %%
# 2번
print((20-5)*3)

# %% [markdown]
# ![image.png](attachment:407c2f5c-93e0-4113-9a28-e77198023629.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>4. 여러 개 문자를 표현하는 문자열 데이터</h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:e0341232-379e-449a-bb6d-f163cb9361a5.png)

# %%
print('Hello')

# %% [markdown]
# ![image.png](attachment:85803fcd-d796-4a4d-b973-cd77ef89db87.png)

# %%
print( 안녕하세요! )

# %% [markdown]
# ![image.png](attachment:89e31f7c-eb39-4003-b2e4-974dbb349815.png)

# %%
# 작은 따옴표를 이용하여 여러분의 이름을 출력해보세요
print('    ')

# %% [markdown]
# ![image.png](attachment:d9acee78-2984-49f9-b2c9-71f510099b44.png)

# %% [markdown]
# ![image.png](attachment:79ed29d2-efbd-49e2-8a6f-f1823c7b4af4.png)

# %%
print('Hello'+'python')
print('안녕하세요'+'!')

# %% [markdown]
# ![image.png](attachment:055579c3-25f6-44d2-b886-6d9bdebae0fc.png)

# %%
print('Hello'+1)

# %% [markdown]
# ![image.png](attachment:1fe5f181-efa3-4c2a-b60e-f182b30f2c7a.png)

# %%
print('Hello'+'101')

# %% [markdown]
# ![image.png](attachment:b13dbeab-03d0-4905-9331-1517ac1593d8.png)

# %% [markdown]
# ![image.png](attachment:486b54d7-fc1c-4711-949d-bf6892bedbf8.png)

# %%
print('안녕'*5)

# %% [markdown]
# ![image.png](attachment:0b3cb55d-685f-4c04-8d72-748a35c0e123.png)

# %%
# 여러분의 이름을 10번 출력하도록 * 연산자를 이용해보세요
print(   )

# %% [markdown]
# ![image.png](attachment:89d02c95-d2f1-4caf-bdfc-05294ed92681.png)

# %%
print('Hello python'[7])

# %% [markdown]
# ![image.png](attachment:14b01ade-282c-436b-8407-981232069322.png)

# %%
# 정답확인
print('Hello python'[0])
print('Hello python'[4])
print('Hello python'[5])
print('Hello python'[9])
print('Hello python'[11])

# %% [markdown]
# ![image.png](attachment:86d06596-2bd1-4084-9569-b4a3cabfb5ea.png)

# %%
print('Hello python'[-5])

# %% [markdown]
# ![image.png](attachment:2f99edfe-3bfb-4378-b2af-fd2eec8c7489.png)

# %%
# 정답 확인
print('Hello python'[-1])
print('Hello python'[-2])
print('Hello python'[-3])
print('Hello python'[-4])
print('Hello python'[-5])

# %% [markdown]
# ![image.png](attachment:88ac4fd0-ab4a-4a3c-940a-f6c4605057a5.png)

# %%
print('Hello python'[6:8])
print('Hello python'[6:10])
print('Hello python'[6:11])
print('Hello python'[6:12])

# %% [markdown]
# ![image.png](attachment:9498bb52-b9b5-4de4-a0dc-b66820fbf35f.png)

# %% [markdown]
# ![image.png](attachment:1f28e093-1a46-47a1-9ee7-ddf598999b59.png)

# %%
# 정답 확인
print('Hello python'[0:3])
print('Hello python'[4:6])
print('Hello python'[5:10])

# %% [markdown]
# ![image.png](attachment:752bb7a3-f16e-4f99-be01-2d642c797e1c.png)

# %%
print('algorithm'[:3])
print('algorithm'[5:])

# %% [markdown]
# ![image.png](attachment:e8593d54-73d4-46f2-a464-97468a118f37.png)

# %%
# 음수 인덱스를 적용하여 'py'를 출력해보세요.
print('Hello python'      )

# %% [markdown]
# ![image.png](attachment:a671b590-cf86-4aff-bbcd-e3caa539828e.png)

# %%
print(len('algorithm'))

# %% [markdown]
# ![image.png](attachment:86064375-6578-4538-94ad-9b37c84930ab.png)

# %%
print('실패란 넘어지는 것이 아니라 \n넘어진 자리에 머무는 것이다.')

# %% [markdown]
# ![image.png](attachment:55d4f161-7c79-4661-947e-a5b1321b8b42.png)

# %%
print('실패란 넘어지는 것이 아니라 \t넘어진 자리에 머무는 것이다.')

# %% [markdown]
# ![image.png](attachment:e70d874d-6c6a-4b2f-a9cf-2a04b0b0047a.png)

# %%
# Hello python에서 Hey를 출력해보세요.
print('Hello python'    + 'Hello python'     )

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>5. 참과 거짓을 판단하는 논리 데이터 </h2>
#
# </div>

# %% [markdown]
# ![image.png](attachment:95c16cc2-9de7-4883-932a-6e9d4154b1e1.png)

# %% [markdown]
# ![image.png](attachment:871e0705-06df-4df0-83a0-3d2922483364.png)

# %%
# 직접 코드를 작성하여 각 데이터가 True인지 False인지 확인해보세요.
# 한 줄 씩 작성해야 합니다.

# %% [markdown]
# ![image.png](attachment:766eecc8-6b3f-44d9-8ca7-2ba18d5c40e9.png)

# %% [markdown]
# ![image.png](attachment:4217299f-f6e7-48a3-ab21-ed595b9ad11d.png)

# %%
print(50==51)
print(10!=7)

# %% [markdown]
# ![image.png](attachment:6c75479e-9c90-40ce-b9ae-fcf89bc740ce.png)

# %% [markdown]
# ![image.png](attachment:07846105-de08-49f7-9c19-22158f0c71b3.png)

# %%
print('Python'=='python')
print('python'=='python')
print('scratch'>'python')
print('안녕'<'파이썬')

# %% [markdown]
# ![image.png](attachment:0fc12793-9c43-4d0f-aa24-ce4e822dd65c.png)

# %% [markdown]
# ![image.png](attachment:4071f26c-224a-4f76-b9a8-f30bfc6475c1.png)

# %% [markdown]
# ![image.png](attachment:408bf4e7-56bb-4cf9-93d3-55d8a66b271b.png)

# %%
print(1<10 and 10==10)
print(10!=7 and 7>10)

# %% [markdown]
# ![image.png](attachment:1dadf429-f2c6-41d6-a73a-421997c2df6c.png)

# %% [markdown]
# ![image.png](attachment:7096f72a-590f-405a-8430-d2534ca74df6.png)
# ![image.png](attachment:02e1ddca-1951-4f56-8ed6-1c07a84bc0e4.png)

# %% [markdown]
# ![image.png](attachment:2357eb82-f22a-49dc-8873-12f96dddc676.png)

# %%
print(2<5 or 7<10)
print(5!=7 or 2>=10)

# %% [markdown]
# ![image.png](attachment:d6d9eac0-580f-44ec-9120-124ed70e0c8d.png)

# %%
print(not 2<5)
print(not 2>5)

# %% [markdown]
# ![image.png](attachment:05bc58e0-5ba3-4155-abf6-a8ed5351ad65.png)

# %% [markdown]
# ![image.png](attachment:c893dd17-bd44-44ed-a679-e1bae5331c78.png)
